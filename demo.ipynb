# %%
import numpy as np
import pandas as pd


# array = np.array([1,2,3,4,5])
# print(array)

df = pd.read_csv('products.csv')

print(df)
# Out:
#     id                                      title    category  \
# 0    1              Essence Mascara Lash Princess      beauty
# 1    2              Eyeshadow Palette with Mirror      beauty
# 2    3                            Powder Canister      beauty
# 3    4                               Red Lipstick      beauty
# 4    5                            Red Nail Polish      beauty
# 5    6                        Calvin Klein CK One  fragrances
# 6    7                    Chanel Coco Noir Eau De  fragrances
# 7    8                               Dior J'adore  fragrances
# 8    9                         Dolce Shine Eau de  fragrances
# 9   10                         Gucci Bloom Eau de  fragrances
# 10  11                       Annibale Colombo Bed   furniture
# 11  12                      Annibale Colombo Sofa   furniture
# 12  13               Bedside Table African Cherry   furniture
# 13  14  Knoll Saarinen Executive Conference Chair   furniture
# ...
